# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Get the dataset and prepare it for analysis and model

# %% [markdown]
# #### Set the index to date

# %%
df = pd.read_csv('USD_INR.csv')
df['Date'] = pd.to_datetime(df["Date"])
df_idx = df.set_index(["Date"], drop=True)
df_idx.head(5)
# Out:
#              Price    Open    High     Low  Change %
# Date
# 2017-08-10  64.165  63.898  64.175  63.855      0.48
# 2017-08-09  63.860  63.780  63.860  63.710      0.26
# 2017-08-08  63.692  63.750  63.785  63.615     -0.23
# 2017-08-07  63.840  63.710  63.865  63.648      0.26
# 2017-08-04  63.675  63.670  63.786  63.572     -0.05

# %% [markdown]
# #### Flip the dataframe

# %%
df_idx = df_idx.sort_index(axis=1, ascending=True)
df_idx = df_idx.iloc[::-1]

# %% [markdown]
# #### Plot the data

# %%
data = df_idx[['Price']]
data.plot(y='Price')

# %%
diff = data.index.values[-1] - data.index.values[0]
days = diff.astype('timedelta64[D]')
days = days / np.timedelta64(1, 'D')
years = int(days/365)
print("Total data: %d years"%years)
print("80 percent data = 1980 to %d"%(1980 + int(0.8*years)))
# Out:
# Total data: 37 years
# 80 percent data = 1980 to 2009

# %% [markdown]
# #### Create training and testing data

# %%
split_date = pd.Timestamp('01-01-2009')

train = data.loc[:split_date]
test = data.loc[split_date:]

ax = train.plot(figsize=(10,12))
test.plot(ax=ax)
plt.legend(['train', 'test'])
plt.show()

# %% [markdown]
# #### Normalize the dataset

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
train_sc = sc.fit_transform(train)
test_sc = sc.transform(test)

# %%
train_sc_df = pd.DataFrame(train_sc, columns=['Y'], index=train.index)
test_sc_df = pd.DataFrame(test_sc, columns=['Y'], index=test.index)

for s in range(1,2):
    train_sc_df['X_{}'.format(s)] = train_sc_df['Y'].shift(s)
    test_sc_df['X_{}'.format(s)] = test_sc_df['Y'].shift(s)

X_train = train_sc_df.dropna().drop('Y', axis=1)
y_train = train_sc_df.dropna().drop('X_1', axis=1)

X_test = test_sc_df.dropna().drop('Y', axis=1)
y_test = test_sc_df.dropna().drop('X_1', axis=1)

X_train = X_train.as_matrix()
y_train = y_train.as_matrix()

X_test = X_test.as_matrix()
y_test = y_test.as_matrix()

# %%
print('Train size: (%d x %d)'%(X_train.shape[0], X_train.shape[1]))
print('Test size: (%d x %d)'%(X_test.shape[0], X_test.shape[1]))
# Out:
# Train size: (7451 x 1)
# Test size: (2245 x 1)

# %% [markdown]
# ## Setup baseline model of SVM Regressor

# %%
from sklearn.svm import SVR
regressor = SVR(kernel='rbf')

# %%
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)
# Out:
# /Users/neelabhpant/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.py:526: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
plt.plot(y_test)
plt.plot(y_pred)

# %%
from sklearn.metrics import r2_score

def adj_r2_score(r2, n, k):
    return 1-((1-r2)*((n-1)/(n-k-1)))

r2_test = r2_score(y_test, y_pred)
print("R-squared is: %f"%r2_test)
# Out:
# R-squared is: -0.963381

# %% [markdown]
# ## Build a Neural Network

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
import keras.backend as K
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### 1 hidden layer with 1 neuron

# %%
K.clear_session()
model = Sequential()
model.add(Dense(1, input_shape=(X_test.shape[1],), activation='tanh', kernel_initializer='lecun_uniform'))
model.compile(optimizer=Adam(lr=0.001), loss='mean_squared_error')
model.fit(X_train, y_train, batch_size=16, epochs=20, verbose=1)
# Out:
# Epoch 1/20
# 7451/7451 [==============================] - 0s - loss: 0.7548
# Epoch 2/20
# 7451/7451 [==============================] - 0s - loss: 0.2337
# Epoch 3/20
# 7451/7451 [==============================] - 0s - loss: 0.1417
# Epoch 4/20
# 7451/7451 [==============================] - 0s - loss: 0.1153
# Epoch 5/20
# 7451/7451 [==============================] - 0s - loss: 0.0922     - ETA: 0s - lo
# Epoch 6/20
# 7451/7451 [==============================] - 0s - loss: 0.0683
# Epoch 7/20
# 7451/7451 [==============================] - 0s - loss: 0.0463
# Epoch 8/20
# 7451/7451 [==============================] - 0s - loss: 0.0290
# Epoch 9/20
# 7451/7451 [==============================] - 0s - loss: 0.0171
# Epoch 10/20
# 7451/7451 [==============================] - 0s - loss: 0.0098
# Epoch 11/20
# 7451/7451 [==============================] - 0s - loss: 0.0058
# Epoch 12/20
# 7451/7451 [==============================] - 0s - loss: 0.0038
# Epoch 13/20
# 7451/7451 [==============================] - 0s - loss: 0.0029
# Epoch 14/20
# 7451/7451 [==============================] - 0s - loss: 0.0026
# Epoch 15/20
# 7451/7451 [==============================] - 0s - loss: 0.0025
# Epoch 16/20
# 7451/7451 [==============================] - 0s - loss: 0.0024
# Epoch 17/20
# 7451/7451 [==============================] - 0s - loss: 0.0024
# Epoch 18/20
# 7451/7451 [==============================] - 0s - loss: 0.0024
# Epoch 19/20
# 7451/7451 [==============================] - 0s - loss: 0.0024
# Epoch 20/20
# 7451/7451 [==============================] - 0s - loss: 0.0024

# %%
y_pred = model.predict(y_test)
plt.plot(y_test)
plt.plot(y_pred)
print('R-Squared: %f'%(r2_score(y_test, y_pred)))
# Out:
# R-Squared: -1.146534

# %% [markdown]
# #### 1 Hidden Layer with 2 neurons and ReLU activation function

# %%
K.clear_session()
model = Sequential()
model.add(Dense(2, input_shape=(X_test.shape[1],), activation='relu', kernel_initializer='lecun_uniform'))
model.add(Dense(1))
model.compile(optimizer=Adam(lr=0.001), loss='mean_squared_error')
model.fit(X_train, y_train, batch_size=16, epochs=20, verbose=1)
# Out:
# Epoch 1/20
# 7451/7451 [==============================] - 0s - loss: 0.3963
# Epoch 2/20
# 7451/7451 [==============================] - 0s - loss: 0.0620
# Epoch 3/20
# 7451/7451 [==============================] - 0s - loss: 0.0190
# Epoch 4/20
# 7451/7451 [==============================] - 0s - loss: 0.0034
# Epoch 5/20
# 7451/7451 [==============================] - 0s - loss: 5.8707e-04
# Epoch 6/20
# 7451/7451 [==============================] - 0s - loss: 2.9939e-04
# Epoch 7/20
# 7451/7451 [==============================] - 0s - loss: 2.7011e-04
# Epoch 8/20
# 7451/7451 [==============================] - 0s - loss: 2.5532e-04
# Epoch 9/20
# 7451/7451 [==============================] - 0s - loss: 2.3916e-04
# Epoch 10/20
# 7451/7451 [==============================] - 0s - loss: 2.2210e-04
# Epoch 11/20
# 7451/7451 [==============================] - 0s - loss: 2.0505e-04
# Epoch 12/20
# 7451/7451 [==============================] - 0s - loss: 1.8709e-04
# Epoch 13/20
# 7451/7451 [==============================] - 0s - loss: 1.6895e-04
# Epoch 14/20
# 7451/7451 [==============================] - 0s - loss: 1.4993e-04
# Epoch 15/20
# 7451/7451 [==============================] - 0s - loss: 1.3115e-04
# Epoch 16/20
# 7451/7451 [==============================] - 0s - loss: 1.1086e-04
# Epoch 17/20
# 7451/7451 [==============================] - 0s - loss: 8.4476e-05
# Epoch 18/20
# 7451/7451 [==============================] - 0s - loss: 5.9275e-05
# Epoch 19/20
# 7451/7451 [==============================] - 0s - loss: 3.9223e-05
# Epoch 20/20
# 7451/7451 [==============================] - 0s - loss: 2.7688e-05

# %%
y_pred = model.predict(y_test)
plt.plot(y_test)
plt.plot(y_pred)
print('R-Squared: %f'%(r2_score(y_test, y_pred)))
# Out:
# R-Squared: 0.999420

# %% [markdown]
# ## Try to predict the difference between consecutive days
# ### This is also known as introducing stationarity in the dataset.
# ### A better test of the model is to predict stationarized data where the mean, standard deviation, autocorrelation are constant over time.
# ### "Because this data is generated using a completely stochastic random walk process. Being able to predict future outcomes of a stochastic process is by definition not possible, and if someone claims to do this, one should be a bit skeptical..." - Vegard Flovik
